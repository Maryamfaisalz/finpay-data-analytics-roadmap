# %%
#Import library
import pandas as pd

# %%
#Load the dataset
df = pd.read_csv(r"C:\Users\marya\OneDrive\Desktop\fintech\finpay-data-analytics-roadmap\pandas\customers_clean.csv")

# %%
df
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 0         C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1         C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 2         C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3         C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4         C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# ..         ...        ...       ...     ...  ...     ...           ...
# 92        C096       Omar    Farooq  Female   37  Jeddah  Saudi Arabia
# 93        C097     Fatima   Hussain  Female   40  Riyadh  Saudi Arabia
# 94        C098       Lina    Shaikh  Female   55  Riyadh  Saudi Arabia
# 95        C099       Sara   Hussain    Male   54  Khobar  Saudi Arabia
# 96        C100       Zaid    Farooq  Female   23  Jeddah  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# ...

# %%
#Select one column 
df["city"]
# Out:
# 0     Jeddah
# 1     Riyadh
# 2     Khobar
# 3     Jeddah
# 4     Dammam
#        ...
# 92    Jeddah
# 93    Riyadh
# 94    Riyadh
# 95    Khobar
# 96    Jeddah
# Name: city, Length: 97, dtype: str

# %%
#Select multiple column
df[["first_name","city"]]
# Out:
#    first_name    city
# 0        Sara  Jeddah
# 1      Maryam  Riyadh
# 2         Ali  Khobar
# 3       Ahmed  Jeddah
# 4        Sara  Dammam
# ..        ...     ...
# 92       Omar  Jeddah
# 93     Fatima  Riyadh
# 94       Lina  Riyadh
# 95       Sara  Khobar
# 96       Zaid  Jeddah
#
# [97 rows x 2 columns]

# %%
#Select specific rows and columns
df.loc[0:5]
# Out:
#   customer_id first_name last_name  gender  age    city       country  \
# 0        C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1        C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 2        C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3        C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4        C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# 5        C006      Ahmed     Iqbal  Female   60   Mecca  Saudi Arabia
#
#   signup_date employment_status  annual_income  credit_score risk_level
# 0  2024-03-12           Student        66868.0         846.0       High
# 1  2024-02-17          Salaried       100990.0         758.0       High
# 2  2024-04-22     Self-Employed       112926.0         503.0        Low
# 3  2025-05-05     Self-Employed        66793.0         547.0     Medium
# 4  2025-02-17          Salaried       102066.5         774.0        Low
# ...

# %%
#Select rows using iloc
df.iloc[0:5]
# Out:
#   customer_id first_name last_name  gender  age    city       country  \
# 0        C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1        C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 2        C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3        C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4        C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
#
#   signup_date employment_status  annual_income  credit_score risk_level
# 0  2024-03-12           Student        66868.0         846.0       High
# 1  2024-02-17          Salaried       100990.0         758.0       High
# 2  2024-04-22     Self-Employed       112926.0         503.0        Low
# 3  2025-05-05     Self-Employed        66793.0         547.0     Medium
# 4  2025-02-17          Salaried       102066.5         774.0        Low

# %%
#Select specific rows and columns
df.loc[0:5,["first_name","city"]]
# Out:
#   first_name    city
# 0       Sara  Jeddah
# 1     Maryam  Riyadh
# 2        Ali  Khobar
# 3      Ahmed  Jeddah
# 4       Sara  Dammam
# 5      Ahmed   Mecca

# %%
#Boolean mask
df[df["age"]>30]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 0         C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 2         C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 4         C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# 5         C006      Ahmed     Iqbal  Female   60   Mecca  Saudi Arabia
# 6         C007      Aisha    Shaikh    Male   34  Riyadh  Saudi Arabia
# ..         ...        ...       ...     ...  ...     ...           ...
# 91        C095        Ali     Iqbal    Male   56   Mecca  Saudi Arabia
# 92        C096       Omar    Farooq  Female   37  Jeddah  Saudi Arabia
# 93        C097     Fatima   Hussain  Female   40  Riyadh  Saudi Arabia
# 94        C098       Lina    Shaikh  Female   55  Riyadh  Saudi Arabia
# 95        C099       Sara   Hussain    Male   54  Khobar  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# ...

# %%
#Multiple Conditions
df[(df["age"]>30) & (df["city"]=="Riyadh")]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 6         C007      Aisha    Shaikh    Male   34  Riyadh  Saudi Arabia
# 14        C015        Ali     Iqbal  Female   41  Riyadh  Saudi Arabia
# 15        C016       Noor   Qureshi    Male   52  Riyadh  Saudi Arabia
# 25        C026       Sara      Khan  Female   41  Riyadh  Saudi Arabia
# 28        C029      Ahmed      Khan    Male   44  Riyadh  Saudi Arabia
# 31        C035       Sara      Khan  Female   59  Riyadh  Saudi Arabia
# 32        C036       Omar     Malik    Male   35  Riyadh  Saudi Arabia
# 35        C039       Noor   Qureshi  Female   36  Riyadh  Saudi Arabia
# 56        C060       Noor     Malik  Female   54  Riyadh  Saudi Arabia
# 58        C062      Aisha   Hussain  Female   57  Riyadh  Saudi Arabia
# 62        C066      Ahmed    Rahman  Female   31  Riyadh  Saudi Arabia
# 64        C068     Maryam      Khan  Female   34  Riyadh  Saudi Arabia
# ...

# %%
#OR condition
df[(df["city"]=="Riyadh") | (df["city"]=="Jeddah")]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 0         C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1         C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 3         C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 6         C007      Aisha    Shaikh    Male   34  Riyadh  Saudi Arabia
# 12        C013       Omar   Qureshi  Female   25  Riyadh  Saudi Arabia
# 14        C015        Ali     Iqbal  Female   41  Riyadh  Saudi Arabia
# 15        C016       Noor   Qureshi    Male   52  Riyadh  Saudi Arabia
# 16        C017       Zaid    Ansari    Male   43  Jeddah  Saudi Arabia
# 18        C019       Sara    Farooq    Male   54  Jeddah  Saudi Arabia
# 20        C021     Fatima    Farooq    Male   27  Jeddah  Saudi Arabia
# 21        C022     Maryam    Ansari    Male   20  Riyadh  Saudi Arabia
# 22        C023        Ali     Malik  Female   52  Jeddah  Saudi Arabia
# ...

# %%
#Using query()
df.query("age > 60")
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 24        C025      Ahmed     Malik  Female  150  Khobar  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# 24  2025-03-18           Student        54200.0         844.0       High

# %%
#Sort data
df.sort_values("annual_income")
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 25        C026       Sara      Khan  Female   41  Riyadh  Saudi Arabia
# 16        C017       Zaid    Ansari    Male   43  Jeddah  Saudi Arabia
# 73        C077     Fatima    Shaikh  Female   37   Mecca  Saudi Arabia
# 79        C083       Sara    Ansari  Female   34  Dammam  Saudi Arabia
# 61        C065       Omar      Syed    Male   45   Mecca  Saudi Arabia
# ..         ...        ...       ...     ...  ...     ...           ...
# 44        C048        Ali     Iqbal  Female   42  Dammam  Saudi Arabia
# 52        C056        Ali     Iqbal  Female   34  Jeddah  Saudi Arabia
# 78        C082     Maryam    Rahman    Male   33  Khobar  Saudi Arabia
# 13        C014      Ahmed      Syed    Male   44  Khobar  Saudi Arabia
# 53        C057     Maryam    Ansari    Male   49  Jeddah  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# ...

# %%
#Sort descending
df.sort_values("annual_income",ascending=False)
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 53        C057     Maryam    Ansari    Male   49  Jeddah  Saudi Arabia
# 13        C014      Ahmed      Syed    Male   44  Khobar  Saudi Arabia
# 78        C082     Maryam    Rahman    Male   33  Khobar  Saudi Arabia
# 52        C056        Ali     Iqbal  Female   34  Jeddah  Saudi Arabia
# 44        C048        Ali     Iqbal  Female   42  Dammam  Saudi Arabia
# ..         ...        ...       ...     ...  ...     ...           ...
# 61        C065       Omar      Syed    Male   45   Mecca  Saudi Arabia
# 79        C083       Sara    Ansari  Female   34  Dammam  Saudi Arabia
# 73        C077     Fatima    Shaikh  Female   37   Mecca  Saudi Arabia
# 16        C017       Zaid    Ansari    Male   43  Jeddah  Saudi Arabia
# 25        C026       Sara      Khan  Female   41  Riyadh  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# ...

# %%
#Count values
df["city"].value_counts()
# Out:
# city
# Riyadh    25
# Khobar    21
# Jeddah    18
# Dammam    18
# Mecca     15
# Name: count, dtype: int64

# %%
#Show customers from Riyadh.
df[df["city"]=="Riyadh"]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 1         C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 6         C007      Aisha    Shaikh    Male   34  Riyadh  Saudi Arabia
# 12        C013       Omar   Qureshi  Female   25  Riyadh  Saudi Arabia
# 14        C015        Ali     Iqbal  Female   41  Riyadh  Saudi Arabia
# 15        C016       Noor   Qureshi    Male   52  Riyadh  Saudi Arabia
# 21        C022     Maryam    Ansari    Male   20  Riyadh  Saudi Arabia
# 25        C026       Sara      Khan  Female   41  Riyadh  Saudi Arabia
# 28        C029      Ahmed      Khan    Male   44  Riyadh  Saudi Arabia
# 31        C035       Sara      Khan  Female   59  Riyadh  Saudi Arabia
# 32        C036       Omar     Malik    Male   35  Riyadh  Saudi Arabia
# 35        C039       Noor   Qureshi  Female   36  Riyadh  Saudi Arabia
# 37        C041      Ahmed   Qureshi    Male   27  Riyadh  Saudi Arabia
# ...

# %%
#Find customers older than 40
df[df["age"]>40]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 2         C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 4         C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# 5         C006      Ahmed     Iqbal  Female   60   Mecca  Saudi Arabia
# 10        C011     Fatima    Ansari  Female   45  Khobar  Saudi Arabia
# 11        C012     Maryam   Qureshi  Female   57  Khobar  Saudi Arabia
# 13        C014      Ahmed      Syed    Male   44  Khobar  Saudi Arabia
# 14        C015        Ali     Iqbal  Female   41  Riyadh  Saudi Arabia
# 15        C016       Noor   Qureshi    Male   52  Riyadh  Saudi Arabia
# 16        C017       Zaid    Ansari    Male   43  Jeddah  Saudi Arabia
# 17        C018       Lina      Khan    Male   43  Dammam  Saudi Arabia
# 18        C019       Sara    Farooq    Male   54  Jeddah  Saudi Arabia
# 22        C023        Ali     Malik  Female   52  Jeddah  Saudi Arabia
# ...

# %%
#List all high-risk customers.
df[df["risk_level"]=="High"]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 0         C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1         C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 7         C008       Omar     Malik  Female   33  Dammam  Saudi Arabia
# 9         C010        Ali    Ansari    Male   40  Khobar  Saudi Arabia
# 10        C011     Fatima    Ansari  Female   45  Khobar  Saudi Arabia
# 13        C014      Ahmed      Syed    Male   44  Khobar  Saudi Arabia
# 15        C016       Noor   Qureshi    Male   52  Riyadh  Saudi Arabia
# 20        C021     Fatima    Farooq    Male   27  Jeddah  Saudi Arabia
# 22        C023        Ali     Malik  Female   52  Jeddah  Saudi Arabia
# 24        C025      Ahmed     Malik  Female  150  Khobar  Saudi Arabia
# 32        C036       Omar     Malik    Male   35  Riyadh  Saudi Arabia
# 34        C038       Sara     Iqbal    Male   37  Dammam  Saudi Arabia
# ...

# %%
#Which customers earn above the average annual income?
average_income = df["annual_income"].mean()
df[df["annual_income"]>average_income]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 2         C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 6         C007      Aisha    Shaikh    Male   34  Riyadh  Saudi Arabia
# 11        C012     Maryam   Qureshi  Female   57  Khobar  Saudi Arabia
# 13        C014      Ahmed      Syed    Male   44  Khobar  Saudi Arabia
# 15        C016       Noor   Qureshi    Male   52  Riyadh  Saudi Arabia
# 18        C019       Sara    Farooq    Male   54  Jeddah  Saudi Arabia
# 20        C021     Fatima    Farooq    Male   27  Jeddah  Saudi Arabia
# 22        C023        Ali     Malik  Female   52  Jeddah  Saudi Arabia
# 26        C027       Omar   Hussain    Male   37  Khobar  Saudi Arabia
# 27        C028        Ali   Qureshi    Male   25  Jeddah  Saudi Arabia
# 28        C029      Ahmed      Khan    Male   44  Riyadh  Saudi Arabia
# 30        C031    Unknown      Syed  Female   52   Mecca  Saudi Arabia
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        97 non-null     str
#  1   first_name         97 non-null     str
#  2   last_name          97 non-null     str
#  3   gender             97 non-null     str
#  4   age                97 non-null     int64
#  5   city               97 non-null     str
#  6   country            97 non-null     str
#  7   signup_date        97 non-null     str
#  8   employment_status  97 non-null     str
#  9   annual_income      97 non-null     float64
#  10  credit_score       97 non-null     float64
#  11  risk_level         97 non-null     str
# dtypes: float64(2), int64(1), str(9)
# memory usage: 9.2 KB

# %%
#Convert the sign up date to datetime
df["signup_date"] = pd.to_datetime(df["signup_date"])

# %%
#Which customers signed up in 2025?
df[df["signup_date"].dt.year==2025]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 3         C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4         C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# 5         C006      Ahmed     Iqbal  Female   60   Mecca  Saudi Arabia
# 11        C012     Maryam   Qureshi  Female   57  Khobar  Saudi Arabia
# 12        C013       Omar   Qureshi  Female   25  Riyadh  Saudi Arabia
# 15        C016       Noor   Qureshi    Male   52  Riyadh  Saudi Arabia
# 19        C020       Noor   Qureshi  Female   33   Mecca  Saudi Arabia
# 23        C024       Omar      Syed  Female   -5  Khobar  Saudi Arabia
# 24        C025      Ahmed     Malik  Female  150  Khobar  Saudi Arabia
# 33        C037       Noor      Syed    Male   55  Dammam  Saudi Arabia
# 37        C041      Ahmed   Qureshi    Male   27  Riyadh  Saudi Arabia
# 39        C043      Aisha    Ansari    Male   42   Mecca  Saudi Arabia
# ...

# %%
#Which cities have the most customers?
df["city"].value_counts()
# Out:
# city
# Riyadh    25
# Khobar    21
# Jeddah    18
# Dammam    18
# Mecca     15
# Name: count, dtype: int64

# %%
#Show customers who are students
df[df["employment_status"]=="Student"]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 0         C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 7         C008       Omar     Malik  Female   33  Dammam  Saudi Arabia
# 11        C012     Maryam   Qureshi  Female   57  Khobar  Saudi Arabia
# 16        C017       Zaid    Ansari    Male   43  Jeddah  Saudi Arabia
# 18        C019       Sara    Farooq    Male   54  Jeddah  Saudi Arabia
# 19        C020       Noor   Qureshi  Female   33   Mecca  Saudi Arabia
# 21        C022     Maryam    Ansari    Male   20  Riyadh  Saudi Arabia
# 22        C023        Ali     Malik  Female   52  Jeddah  Saudi Arabia
# 24        C025      Ahmed     Malik  Female  150  Khobar  Saudi Arabia
# 35        C039       Noor   Qureshi  Female   36  Riyadh  Saudi Arabia
# 36        C040        Ali     Malik    Male   60  Dammam  Saudi Arabia
# 37        C041      Ahmed   Qureshi    Male   27  Riyadh  Saudi Arabia
# ...

# %%
#Show female customers from Riyadh
df[(df["gender"]=="Female") & (df["city"]=="Riyadh")]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 1         C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 12        C013       Omar   Qureshi  Female   25  Riyadh  Saudi Arabia
# 14        C015        Ali     Iqbal  Female   41  Riyadh  Saudi Arabia
# 25        C026       Sara      Khan  Female   41  Riyadh  Saudi Arabia
# 31        C035       Sara      Khan  Female   59  Riyadh  Saudi Arabia
# 35        C039       Noor   Qureshi  Female   36  Riyadh  Saudi Arabia
# 43        C047     Maryam   Hussain  Female   21  Riyadh  Saudi Arabia
# 49        C053       Lina    Ansari  Female   30  Riyadh  Saudi Arabia
# 56        C060       Noor     Malik  Female   54  Riyadh  Saudi Arabia
# 58        C062      Aisha   Hussain  Female   57  Riyadh  Saudi Arabia
# 62        C066      Ahmed    Rahman  Female   31  Riyadh  Saudi Arabia
# 64        C068     Maryam      Khan  Female   34  Riyadh  Saudi Arabia
# ...

# %%
#Show salaried customers earning more than 100,000
df[(df["employment_status"] == "Salaried") & (df["annual_income"]>100000)]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 1         C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 4         C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# 17        C018       Lina      Khan    Male   43  Dammam  Saudi Arabia
# 20        C021     Fatima    Farooq    Male   27  Jeddah  Saudi Arabia
# 26        C027       Omar   Hussain    Male   37  Khobar  Saudi Arabia
# 30        C031    Unknown      Syed  Female   52   Mecca  Saudi Arabia
# 32        C036       Omar     Malik    Male   35  Riyadh  Saudi Arabia
# 42        C046      Aisha      Khan    Male   45  Dammam  Saudi Arabia
# 50        C054       Noor    Ansari    Male   29  Riyadh  Saudi Arabia
# 54        C058     Fatima    Farooq  Female   55  Khobar  Saudi Arabia
# 56        C060       Noor     Malik  Female   54  Riyadh  Saudi Arabia
# 63        C067     Fatima     Malik  Female   37  Khobar  Saudi Arabia
# ...

# %%
#Find customers with a credit score above 750.
df[df["credit_score"]>750]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 0         C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1         C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 4         C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# 6         C007      Aisha    Shaikh    Male   34  Riyadh  Saudi Arabia
# 7         C008       Omar     Malik  Female   33  Dammam  Saudi Arabia
# 8         C009       Omar   Qureshi    Male   30  Khobar  Saudi Arabia
# 9         C010        Ali    Ansari    Male   40  Khobar  Saudi Arabia
# 12        C013       Omar   Qureshi  Female   25  Riyadh  Saudi Arabia
# 15        C016       Noor   Qureshi    Male   52  Riyadh  Saudi Arabia
# 16        C017       Zaid    Ansari    Male   43  Jeddah  Saudi Arabia
# 17        C018       Lina      Khan    Male   43  Dammam  Saudi Arabia
# 18        C019       Sara    Farooq    Male   54  Jeddah  Saudi Arabia
# ...

# %%
#Which customers have both a high risk level and a credit score below 600
df[(df["risk_level"]=="High") & (df["credit_score"]<600)]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 20        C021     Fatima    Farooq    Male   27  Jeddah  Saudi Arabia
# 61        C065       Omar      Syed    Male   45   Mecca  Saudi Arabia
# 63        C067     Fatima     Malik  Female   37  Khobar  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# 20  2024-04-25          Salaried       128627.0         510.0       High
# 61  2024-10-15           Student        47104.0         542.0       High
# 63  2024-05-09          Salaried       163288.0         509.0       High

# %%
#Show customers between ages 25 and 35.
df[df["age"].between(25,35)]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 0         C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 3         C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 6         C007      Aisha    Shaikh    Male   34  Riyadh  Saudi Arabia
# 7         C008       Omar     Malik  Female   33  Dammam  Saudi Arabia
# 8         C009       Omar   Qureshi    Male   30  Khobar  Saudi Arabia
# 12        C013       Omar   Qureshi  Female   25  Riyadh  Saudi Arabia
# 19        C020       Noor   Qureshi  Female   33   Mecca  Saudi Arabia
# 20        C021     Fatima    Farooq    Male   27  Jeddah  Saudi Arabia
# 27        C028        Ali   Qureshi    Male   25  Jeddah  Saudi Arabia
# 32        C036       Omar     Malik    Male   35  Riyadh  Saudi Arabia
# 37        C041      Ahmed   Qureshi    Male   27  Riyadh  Saudi Arabia
# 40        C044       Omar   Hussain    Male   31  Dammam  Saudi Arabia
# ...

# %%
#Which city has the highest average annual income?
df.groupby("city")["annual_income"].mean().sort_values(ascending=False)
# Out:
# city
# Jeddah    115676.055556
# Khobar    115207.952381
# Dammam    109768.694444
# Riyadh    100499.500000
# Mecca      97622.733333
# Name: annual_income, dtype: float64

# %%
#Which employment status has the highest number of customers?
df["employment_status"].value_counts()
# Out:
# employment_status
# Self-Employed    34
# Student          31
# Salaried         29
# Unknown           3
# Name: count, dtype: int64

# %%
#Display the top 10 highest-income customers?
df["annual_income"].sort_values(ascending=False).head(10)
# Out:
# 53    179233.0
# 13    178704.0
# 78    177530.0
# 52    175779.0
# 44    174066.0
# 30    173124.0
# 92    168902.0
# 80    168680.0
# 69    168503.0
# 27    167307.0
# Name: annual_income, dtype: float64

# %%
#Show customers sorted by signup date (newest first)?
df.sort_values("signup_date",ascending=False)
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 3         C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 91        C095        Ali     Iqbal    Male   56   Mecca  Saudi Arabia
# 37        C041      Ahmed   Qureshi    Male   27  Riyadh  Saudi Arabia
# 33        C037       Noor      Syed    Male   55  Dammam  Saudi Arabia
# 11        C012     Maryam   Qureshi  Female   57  Khobar  Saudi Arabia
# ..         ...        ...       ...     ...  ...     ...           ...
# 50        C054       Noor    Ansari    Male   29  Riyadh  Saudi Arabia
# 38        C042     Fatima      Syed    Male   47  Jeddah  Saudi Arabia
# 90        C094     Maryam    Farooq  Female   25   Mecca  Saudi Arabia
# 69        C073      Ahmed     Malik    Male   52  Dammam  Saudi Arabia
# 45        C049       Zaid    Ansari  Female   22  Khobar  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# ...

# %%
#Show customers sorted by signup date (newest first)
df.sort_values("signup_date",ascending=False)
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 3         C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 91        C095        Ali     Iqbal    Male   56   Mecca  Saudi Arabia
# 37        C041      Ahmed   Qureshi    Male   27  Riyadh  Saudi Arabia
# 33        C037       Noor      Syed    Male   55  Dammam  Saudi Arabia
# 11        C012     Maryam   Qureshi  Female   57  Khobar  Saudi Arabia
# ..         ...        ...       ...     ...  ...     ...           ...
# 50        C054       Noor    Ansari    Male   29  Riyadh  Saudi Arabia
# 38        C042     Fatima      Syed    Male   47  Jeddah  Saudi Arabia
# 90        C094     Maryam    Farooq  Female   25   Mecca  Saudi Arabia
# 69        C073      Ahmed     Malik    Male   52  Dammam  Saudi Arabia
# 45        C049       Zaid    Ansari  Female   22  Khobar  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# ...

# %%
#Which country has the most customers?
df["country"].value_counts()
# Out:
# country
# Saudi Arabia    97
# Name: count, dtype: int64

# %%
#Show customers whose first name starts with the letter "A".
df[df["first_name"].str.startswith("A")]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 2         C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3         C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 5         C006      Ahmed     Iqbal  Female   60   Mecca  Saudi Arabia
# 6         C007      Aisha    Shaikh    Male   34  Riyadh  Saudi Arabia
# 9         C010        Ali    Ansari    Male   40  Khobar  Saudi Arabia
# 13        C014      Ahmed      Syed    Male   44  Khobar  Saudi Arabia
# 14        C015        Ali     Iqbal  Female   41  Riyadh  Saudi Arabia
# 22        C023        Ali     Malik  Female   52  Jeddah  Saudi Arabia
# 24        C025      Ahmed     Malik  Female  150  Khobar  Saudi Arabia
# 27        C028        Ali   Qureshi    Male   25  Jeddah  Saudi Arabia
# 28        C029      Ahmed      Khan    Male   44  Riyadh  Saudi Arabia
# 36        C040        Ali     Malik    Male   60  Dammam  Saudi Arabia
# ...

# %%
#Which customers have missing credit scores?
df[df["credit_score"].isna()]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, age, city, country, signup_date, employment_status, annual_income, credit_score, risk_level]
# Index: []

# %%
#Show the youngest five customers.
df.sort_values("age",ascending=True).head(5)
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 23        C024       Omar      Syed  Female   -5  Khobar  Saudi Arabia
# 29        C030     Maryam    Farooq    Male    0  Dammam  Saudi Arabia
# 21        C022     Maryam    Ansari    Male   20  Riyadh  Saudi Arabia
# 43        C047     Maryam   Hussain  Female   21  Riyadh  Saudi Arabia
# 60        C064       Noor   Hussain  Female   21  Khobar  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# 23  2025-02-17     Self-Employed        89914.0         548.0        Low
# 29  2024-04-21          Salaried        55979.0         660.0        Low
# 21  2024-12-28           Student        55433.0         617.0        Low
# 43  2025-03-25     Self-Employed        86810.0         797.0     Medium
# 60  2024-06-21           Student       145989.0         584.0     Medium
