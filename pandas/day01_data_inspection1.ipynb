# %%
#Import pandas 
import pandas as pd

# %%
#Load the dataset 
df = pd.read_csv(r"C:\Users\marya\OneDrive\Desktop\fintech\finpay-data-analytics-roadmap\datasets\customers_dirty.csv")
df
# Out:
#     customer_id first_name last_name  gender  age    city       country  \
# 0          C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1          C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 2          C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3          C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4          C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# ..          ...        ...       ...     ...  ...     ...           ...
# 97         C098       Lina    Shaikh  Female   55  Riyadh  Saudi Arabia
# 98         C099       Sara   Hussain    Male   54  Khobar  Saudi Arabia
# 99         C100       Zaid    Farooq  Female   23  Jeddah  Saudi Arabia
# 100        C010        Ali    Ansari    Male   40  Khobar  Saudi Arabia
# 101        C041  Different   Qureshi    Male   27  Riyadh  Saudi Arabia
#
#     signup_date employment_status annual_income  credit_score risk_level
# ...

# %%
#Display the first 10 rows
df.head()
# Out:
#   customer_id first_name last_name  gender  age    city       country  \
# 0        C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1        C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 2        C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3        C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4        C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
#
#   signup_date employment_status annual_income  credit_score risk_level
# 0  2024-03-12           Student         66868         846.0       High
# 1  2024-02-17          Salaried        100990         758.0       High
# 2  2024-04-22     Self-Employed        112926         503.0        Low
# 3  2025-05-05     Self-Employed         66793         547.0     Medium
# 4  2025-02-17          Salaried           NaN         774.0        Low

# %%
#Display the last 10 rows 
df.tail()
# Out:
#     customer_id first_name last_name  gender  age    city       country  \
# 97         C098       Lina    Shaikh  Female   55  Riyadh  Saudi Arabia
# 98         C099       Sara   Hussain    Male   54  Khobar  Saudi Arabia
# 99         C100       Zaid    Farooq  Female   23  Jeddah  Saudi Arabia
# 100        C010        Ali    Ansari    Male   40  Khobar  Saudi Arabia
# 101        C041  Different   Qureshi    Male   27  Riyadh  Saudi Arabia
#
#     signup_date employment_status annual_income  credit_score risk_level
# 97   2024-08-20          Salaried        122448         629.0     Medium
# 98   2024-07-30          Salaried         89173         765.0     Medium
# 99   2024-05-16           Student         74344         647.0     Medium
# 100  2024-05-17          Salaried         95307         790.0       High
# 101  2025-04-28           Student         79073         779.0        Low

# %%
#How many rows and columns?
df.shape
# Out:
# (102, 12)

# %%
#Display column names
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender', 'age', 'city',
#        'country', 'signup_date', 'employment_status', 'annual_income',
#        'credit_score', 'risk_level'],
#       dtype='str')

# %%
#Display data types
df.dtypes
# Out:
# customer_id              str
# first_name               str
# last_name                str
# gender                   str
# age                    int64
# city                     str
# country                  str
# signup_date              str
# employment_status        str
# annual_income            str
# credit_score         float64
# risk_level               str
# dtype: object

# %%
#Display dataset information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        102 non-null    str
#  1   first_name         101 non-null    str
#  2   last_name          102 non-null    str
#  3   gender             102 non-null    str
#  4   age                102 non-null    int64
#  5   city               102 non-null    str
#  6   country            102 non-null    str
#  7   signup_date        102 non-null    str
#  8   employment_status  101 non-null    str
#  9   annual_income      101 non-null    str
#  10  credit_score       101 non-null    float64
#  11  risk_level         102 non-null    str
# dtypes: float64(1), int64(1), str(10)
# memory usage: 9.7 KB

# %%
#Summary Statistics
df.describe()
# Out:
#               age  credit_score
# count  102.000000    101.000000
# mean    40.960784    691.237624
# std     16.504378    115.762615
# min     -5.000000    150.000000
# 25%     33.000000    618.000000
# 50%     40.000000    696.000000
# 75%     50.750000    782.000000
# max    150.000000    950.000000

# %%
#Check missing values
df.isnull().sum()
# Out:
# customer_id          0
# first_name           1
# last_name            0
# gender               0
# age                  0
# city                 0
# country              0
# signup_date          0
# employment_status    1
# annual_income        1
# credit_score         1
# risk_level           0
# dtype: int64

# %%
#Dsiplay only columns containing missing values
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# first_name           1
# employment_status    1
# annual_income        1
# credit_score         1
# dtype: int64

# %%
#Count total missing values 
df.isnull().sum().sum()
# Out:
# np.int64(4)

# %%
#Count duplicate rows 
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
#Are customer IDs unique 
df["customer_id"].is_unique
# Out:
# False

# %%
#Display duplicate customer IDs
df[df["customer_id"].duplicated()]
# Out:
#     customer_id first_name last_name gender  age    city       country  \
# 100        C010        Ali    Ansari   Male   40  Khobar  Saudi Arabia
# 101        C041  Different   Qureshi   Male   27  Riyadh  Saudi Arabia
#
#     signup_date employment_status annual_income  credit_score risk_level
# 100  2024-05-17          Salaried         95307         790.0       High
# 101  2025-04-28           Student         79073         779.0        Low

# %%
#Checking duplicate values
df["customer_id"].duplicated().sum()
# Out:
# np.int64(2)

# %%
#Unique Gender Values 
df["gender"].unique()
# Out:
# <StringArray>
# ['Female', 'Male', ' male ', 'MALE', 'F']
# Length: 5, dtype: str

# %%
#Count gender values
df["gender"].value_counts()
# Out:
# gender
# Female    51
# Male      48
#  male      1
# MALE       1
# F          1
# Name: count, dtype: int64

# %%
#Unique cities
df["city"].unique()
# Out:
# <StringArray>
# ['Jeddah', 'Riyadh', 'Khobar', 'Dammam', 'Mecca', ' riyadh ', 'RIYADH']
# Length: 7, dtype: str

# %%
#Employment Status 
df["employment_status"].value_counts()
# Out:
# employment_status
# Student          35
# Self-Employed    34
# Salaried         30
# Unknown           1
# -                 1
# Name: count, dtype: int64

# %%
#Risk level counts 
df["risk_level"].value_counts()
# Out:
# risk_level
# Low       40
# High      31
# Medium    31
# Name: count, dtype: int64

# %%
#Customers younger than 18 
df[df["age"]<18]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 23        C024       Omar      Syed  Female   -5  Khobar  Saudi Arabia
# 29        C030     Maryam    Farooq    Male    0  Dammam  Saudi Arabia
#
#    signup_date employment_status annual_income  credit_score risk_level
# 23  2025-02-17     Self-Employed         89914         548.0        Low
# 29  2024-04-21          Salaried         55979         660.0        Low

# %%
#Customers older than 100 
df[df["age"]>100]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 24        C025      Ahmed     Malik  Female  150  Khobar  Saudi Arabia
#
#    signup_date employment_status annual_income  credit_score risk_level
# 24  2025-03-18           Student         54200         844.0       High

# %%
#Negative Income
df[df["annual_income"]<0]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 25        C026       Sara      Khan  Female   41  Riyadh  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# 25  2024-05-07          Salaried       -45000.0         774.0     Medium

# %%
#Changing datatype of annual income from str to float
df["annual_income"] = pd.to_numeric(df["annual_income"],errors = "coerce")

# %%
#credit scores below 300
df[df["credit_score"]<300]
# Out:
#    customer_id first_name last_name gender  age    city       country  \
# 27        C028        Ali   Qureshi   Male   25  Jeddah  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# 27  2024-03-26     Self-Employed       167307.0         150.0        Low

# %%
#credit score above 850 
df[df["credit_score"]>850]
# Out:
#    customer_id first_name last_name gender  age    city       country  \
# 26        C027       Omar   Hussain   Male   37  Khobar  Saudi Arabia
#
#    signup_date employment_status  annual_income  credit_score risk_level
# 26  2024-05-07          Salaried       156164.0         950.0        Low

# %%
#youngest customer
df["age"].min()
# Out:
# np.int64(-5)

# %%
#oldest customer
df["age"].max()
# Out:
# np.int64(150)

# %%
#Display signup dates
df["signup_date"].head(10)
# Out:
# 0    2024-03-12
# 1    2024-02-17
# 2    2024-04-22
# 3    2025-05-05
# 4    2025-02-17
# 5    2025-03-29
# 6    2024-07-13
# 7    2024-12-25
# 8    2024-07-13
# 9    2024-05-17
# Name: signup_date, dtype: str

# %%
#Convert to datetime
df["signup_date"] = pd.to_datetime(df["signup_date"],format="mixed",dayfirst=True)
df["signup_date"]
# Out:
# 0     2024-12-03
# 1     2024-02-17
# 2     2024-04-22
# 3     2025-05-05
# 4     2025-02-17
#          ...
# 97    2024-08-20
# 98    2024-07-30
# 99    2024-05-16
# 100   2024-05-17
# 101   2025-04-28
# Name: signup_date, Length: 102, dtype: datetime64[us]

# %%
pd.to_datetime?
# Out:
# Signature:
# pd.to_datetime(
#     arg: 'DatetimeScalarOrArrayConvertible | DictConvertible',
#     errors: 'DateTimeErrorChoices' = 'raise',
#     dayfirst: 'bool' = False,
#     yearfirst: 'bool' = False,
#     utc: 'bool' = False,
#     format: 'str | None' = None,
#     exact: 'bool | lib.NoDefault' = <no_default>,
#     unit: 'str | None' = None,
#     origin: 'str' = 'unix',
#     cache: 'bool' = True,
# ) -> 'DatetimeIndex | Series | DatetimeScalar | NaTType'
# Docstring:
# Convert argument to datetime.
#
# This function converts a scalar, array-like, :class:`Series` or
# :class:`DataFrame`/dict-like to a pandas datetime object.
#
# Parameters
# ----------
# arg : int, float, str, datetime, list, tuple, 1-d array, Series, DataFrame/dict-like
#     The object to convert to a datetime. If a :class:`DataFrame` is provided, the
#     method expects minimally the following columns: :const:`"year"`,
#     :const:`"month"`, :const:`"day"`. The column "year"
# ...

# %%
df.head()
# Out:
#   customer_id first_name last_name  gender  age    city       country  \
# 0        C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1        C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 2        C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3        C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4        C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
#
#   signup_date employment_status  annual_income  credit_score risk_level
# 0  2024-12-03           Student        66868.0         846.0       High
# 1  2024-02-17          Salaried       100990.0         758.0       High
# 2  2024-04-22     Self-Employed       112926.0         503.0        Low
# 3  2025-05-05     Self-Employed        66793.0         547.0     Medium
# 4  2025-02-17          Salaried            NaN         774.0        Low

# %%
df[df["customer_id"].duplicated()]
# Out:
#     customer_id first_name last_name gender  age    city       country  \
# 100        C010        Ali    Ansari   Male   40  Khobar  Saudi Arabia
# 101        C041  Different   Qureshi   Male   27  Riyadh  Saudi Arabia
#
#     signup_date employment_status  annual_income  credit_score risk_level
# 100  2024-05-17          Salaried        95307.0         790.0       High
# 101  2025-04-28           Student        79073.0         779.0        Low

# %%
#Check for leading and trailing spaces in string columns
df["city"] = df["city"].str.strip()

# %%
df[df["customer_id"].str.startswith("C")]
# Out:
#     customer_id first_name last_name  gender  age    city       country  \
# 0          C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1          C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 2          C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3          C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4          C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# ..          ...        ...       ...     ...  ...     ...           ...
# 97         C098       Lina    Shaikh  Female   55  Riyadh  Saudi Arabia
# 98         C099       Sara   Hussain    Male   54  Khobar  Saudi Arabia
# 99         C100       Zaid    Farooq  Female   23  Jeddah  Saudi Arabia
# 100        C010        Ali    Ansari    Male   40  Khobar  Saudi Arabia
# 101        C041  Different   Qureshi    Male   27  Riyadh  Saudi Arabia
#
#     signup_date employment_status  annual_income  credit_score risk_level
# ...

# %%
df["city"].nunique()
# Out:
# 7

# %%
df["employment_status"].nunique()
# Out:
# 5

# %%
df["country"].nunique()
# Out:
# 2

# %%
df["city"].value_counts()
# Out:
# city
# Riyadh    24
# Khobar    23
# Jeddah    19
# Dammam    18
# Mecca     16
# riyadh     1
# RIYADH     1
# Name: count, dtype: int64

# %%
df["employment_status"].value_counts()
# Out:
# employment_status
# Student          35
# Self-Employed    34
# Salaried         30
# Unknown           1
# -                 1
# Name: count, dtype: int64

# %%
df["risk_level"].value_counts()
# Out:
# risk_level
# Low       40
# High      31
# Medium    31
# Name: count, dtype: int64
