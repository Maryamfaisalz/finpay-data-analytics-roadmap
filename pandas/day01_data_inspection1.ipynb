# %%
#Import pandas 
import pandas as pd

# %%
#Load the dataset 
df = pd.read_csv(r"C:\Users\marya\OneDrive\Desktop\fintech\finpay-data-analytics-roadmap\datasets\customers_dirty.csv")
df
# Out:
#     customer_id first_name last_name  gender  age    city       country  \
# 0          C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1          C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 2          C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3          C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4          C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
# ..          ...        ...       ...     ...  ...     ...           ...
# 97         C098       Lina    Shaikh  Female   55  Riyadh  Saudi Arabia
# 98         C099       Sara   Hussain    Male   54  Khobar  Saudi Arabia
# 99         C100       Zaid    Farooq  Female   23  Jeddah  Saudi Arabia
# 100        C010        Ali    Ansari    Male   40  Khobar  Saudi Arabia
# 101        C041  Different   Qureshi    Male   27  Riyadh  Saudi Arabia
#
#     signup_date employment_status annual_income  credit_score risk_level
# ...

# %%
#Display the first 10 rows
df.head()
# Out:
#   customer_id first_name last_name  gender  age    city       country  \
# 0        C001       Sara      Khan  Female   35  Jeddah  Saudi Arabia
# 1        C002     Maryam     Iqbal  Female   22  Riyadh  Saudi Arabia
# 2        C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 3        C004      Ahmed     Malik  Female   29  Jeddah  Saudi Arabia
# 4        C005       Sara     Malik  Female   58  Dammam  Saudi Arabia
#
#   signup_date employment_status annual_income  credit_score risk_level
# 0  2024-03-12           Student         66868         846.0       High
# 1  2024-02-17          Salaried        100990         758.0       High
# 2  2024-04-22     Self-Employed        112926         503.0        Low
# 3  2025-05-05     Self-Employed         66793         547.0     Medium
# 4  2025-02-17          Salaried           NaN         774.0        Low

# %%
#Display the last 10 rows 
df.tail()
# Out:
#     customer_id first_name last_name  gender  age    city       country  \
# 97         C098       Lina    Shaikh  Female   55  Riyadh  Saudi Arabia
# 98         C099       Sara   Hussain    Male   54  Khobar  Saudi Arabia
# 99         C100       Zaid    Farooq  Female   23  Jeddah  Saudi Arabia
# 100        C010        Ali    Ansari    Male   40  Khobar  Saudi Arabia
# 101        C041  Different   Qureshi    Male   27  Riyadh  Saudi Arabia
#
#     signup_date employment_status annual_income  credit_score risk_level
# 97   2024-08-20          Salaried        122448         629.0     Medium
# 98   2024-07-30          Salaried         89173         765.0     Medium
# 99   2024-05-16           Student         74344         647.0     Medium
# 100  2024-05-17          Salaried         95307         790.0       High
# 101  2025-04-28           Student         79073         779.0        Low

# %%
#How many rows and columns?
df.shape
# Out:
# (102, 12)

# %%
#Display column names
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender', 'age', 'city',
#        'country', 'signup_date', 'employment_status', 'annual_income',
#        'credit_score', 'risk_level'],
#       dtype='str')

# %%
#Display data types
df.dtypes
# Out:
# customer_id              str
# first_name               str
# last_name                str
# gender                   str
# age                    int64
# city                     str
# country                  str
# signup_date              str
# employment_status        str
# annual_income            str
# credit_score         float64
# risk_level               str
# dtype: object

# %%
#Display dataset information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        102 non-null    str
#  1   first_name         101 non-null    str
#  2   last_name          102 non-null    str
#  3   gender             102 non-null    str
#  4   age                102 non-null    int64
#  5   city               102 non-null    str
#  6   country            102 non-null    str
#  7   signup_date        102 non-null    str
#  8   employment_status  101 non-null    str
#  9   annual_income      101 non-null    str
#  10  credit_score       101 non-null    float64
#  11  risk_level         102 non-null    str
# dtypes: float64(1), int64(1), str(10)
# memory usage: 9.7 KB

# %%
#Summary Statistics for numeric columns 
df.describe()
# Out:
#               age  credit_score
# count  102.000000    101.000000
# mean    40.960784    691.237624
# std     16.504378    115.762615
# min     -5.000000    150.000000
# 25%     33.000000    618.000000
# 50%     40.000000    696.000000
# 75%     50.750000    782.000000
# max    150.000000    950.000000

# %%
#Check missing values
df.isnull().sum()
# Out:
# customer_id          0
# first_name           1
# last_name            0
# gender               0
# age                  0
# city                 0
# country              0
# signup_date          0
# employment_status    1
# annual_income        1
# credit_score         1
# risk_level           0
# dtype: int64

# %%
#Count total missing values 
df.isnull().sum().sum()
# Out:
# np.int64(4)

# %%
#Count duplicate rows 
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
#Displays all duplicate rows in the dataframe
df[df.duplicated()]
# Out:
#     customer_id first_name last_name gender  age    city       country  \
# 100        C010        Ali    Ansari   Male   40  Khobar  Saudi Arabia
#
#     signup_date employment_status annual_income  credit_score risk_level
# 100  2024-05-17          Salaried         95307         790.0       High

# %%
#check unique values
df.nunique()
# Out:
# customer_id          100
# first_name            11
# last_name             10
# gender                 5
# age                   39
# city                   7
# country                2
# signup_date           91
# employment_status      5
# annual_income         99
# credit_score          89
# risk_level             3
# dtype: int64

# %% [markdown]
# Frequency Analysis

# %%
df["city"].value_counts()
# Out:
# city
# Riyadh      24
# Khobar      23
# Jeddah      19
# Dammam      18
# Mecca       16
#  riyadh      1
# RIYADH       1
# Name: count, dtype: int64

# %%
df["employment_status"].value_counts()
# Out:
# employment_status
# Student          35
# Self-Employed    34
# Salaried         30
# Unknown           1
# -                 1
# Name: count, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    51
# Male      48
#  male      1
# MALE       1
# F          1
# Name: count, dtype: int64

# %%
df["risk_level"].value_counts()
# Out:
# risk_level
# Low       40
# High      31
# Medium    31
# Name: count, dtype: int64

# %% [markdown]
# Numerical Exploration

# %%
df["age"].min()
# Out:
# np.int64(-5)

# %%
df["age"].max()
# Out:
# np.int64(150)

# %%
df["age"].mean()
# Out:
# np.float64(40.96078431372549)

# %%
df["annual_income"] = pd.to_numeric(df["annual_income"],errors="coerce")

# %%
df["annual_income"].mean()
# Out:
# np.float64(107705.67)

# %%
df["credit_score"].mean()
# Out:
# np.float64(691.2376237623762)

# %% [markdown]
# Business Questions:
#
# How many customers are there?
#
# 102 customers

# %% [markdown]
# What information do we collect?
#
# The datasets collect information about each customer's:
# Customer ID
#
# First Name
#
# Last Name
#
# Gender
#
# Age
#
# City
#
# Country
#
# Signup Date
#
# Employment Status
#
# Annual Income
#
# Credit Score
#
# Risk Level

# %% [markdown]
# Which columns are categorical?
#
# customer_id, first_name, last_name, gender, city, country, employment_status, risk_level

# %% [markdown]
# Which columns are numerical?
#
# age, annual_income, credit_score

# %% [markdown]
# Which columns might need cleaning?
#
# first_name, employment_status, annual_income, credit_risk, signup-date, city, gender,customer_id

# %% [markdown]
# What could each department (Finance, Marketing, Risk, Operations) use from this dataset?
#
# Finance Team - Understand customer financial strength and potential profitability
#
# Marketing Team - Segment customers and plan targeted campaigns
#
# Risk Team - Evaluate whether customers are likely to repay BNPL installments
#
# Operations Team - Maintain accurate customer records and support daily operations
