# %%
#Import pandas and numpy
import pandas as pd
import numpy as np

# %%
#Load the dataset
df = pd.read_csv(r"C:\Users\marya\OneDrive\Desktop\fintech\finpay-data-analytics-roadmap\pandas\customers_features.csv")

# %%
#What is the average annual income?
income = df["annual_income"].to_numpy()
np.mean(income)
# Out:
# np.float64(107775.26804123711)

# %%
#What is the median annual income?
np.median(income)
# Out:
# np.float64(102066.5)

# %%
#What is the highest annual income?
np.max(income)
# Out:
# np.float64(179233.0)

# %%
#What is the lowest annual income?
np.min(income)
# Out:
# np.float64(-45000.0)

# %%
#What is the 90th percentile of annual income?
np.percentile(income,90)
# Out:
# np.float64(167271.6)

# %%
#Which customers earn above the average income?
average_income = np.mean(income)
df[income>average_income]
# Out:
#    customer_id first_name last_name  gender  age    city       country  \
# 2         C003        Ali   Qureshi    Male   54  Khobar  Saudi Arabia
# 6         C007      Aisha    Shaikh    Male   34  Riyadh  Saudi Arabia
# 11        C012     Maryam   Qureshi  Female   57  Khobar  Saudi Arabia
# 13        C014      Ahmed      Syed    Male   44  Khobar  Saudi Arabia
# 15        C016       Noor   Qureshi    Male   52  Riyadh  Saudi Arabia
# 18        C019       Sara    Farooq    Male   54  Jeddah  Saudi Arabia
# 20        C021     Fatima    Farooq    Male   27  Jeddah  Saudi Arabia
# 22        C023        Ali     Malik  Female   52  Jeddah  Saudi Arabia
# 26        C027       Omar   Hussain    Male   37  Khobar  Saudi Arabia
# 27        C028        Ali   Qureshi    Male   25  Jeddah  Saudi Arabia
# 28        C029      Ahmed      Khan    Male   44  Riyadh  Saudi Arabia
# 30        C031    Unknown      Syed  Female   52   Mecca  Saudi Arabia
# ...

# %%
#How many customers earn about SAR 100,000
np.sum(income>100000)
# Out:
# np.int64(51)
